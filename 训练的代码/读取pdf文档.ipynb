# %%
from io import StringIO
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfinterp import process_pdf
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
import re

# %%
file_path = "C:\\Users\\86139\\Desktop\\习近平在宁德.pdf"

# %%
with open(file_path,'rb') as fp:
    resource_manager = PDFResourceManager()
    return_str = StringIO()
    lap_params = LAParams()
    device = TextConverter(resource_manager,return_str,laparams=lap_params)
    process_pdf(resource_manager,device,fp)
    device.close()
    content = return_str.getvalue()
    return_str.close()
    print(re.sub('\s+','',content))

# %%
print(content)

# %%
import pdfplumber
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-b3d6737fd8e1> in <module>
# ----> 1 import pdfplumber
#
# D:\anaconda\lib\site-packages\pdfplumber\__init__.py in <module>
#      12 from . import utils
#      13 from ._version import __version__
# ---> 14 from .pdf import PDF
#      15
#      16 open = PDF.open
#
# D:\anaconda\lib\site-packages\pdfplumber\pdf.py in <module>
#       7
#       8 from pdfminer.layout import LAParams
# ----> 9 from pdfminer.pdfdocument import PDFDocument
#      10 from pdfminer.pdfinterp import PDFResourceManager
#      11 from pdfminer.pdfpage import PDFPage
#
# D:\anaconda\lib\site-packages\pdfminer\pdfdocument.py in <module>
#      27 from .data_structures import NumberTree
#      28 from .pdfparser import PDFSyntaxError, PDFParser, PDFStreamParser
# ---> 29 from .pdftypes import (
#      30     DecipherCallable,
#      31     PDFException,
#
# ImportError: cannot import name 'DecipherCallable' from 'pdfminer.pdftypes' (D:\anaconda\lib\site-packages\pdfminer\pdftypes.py)
