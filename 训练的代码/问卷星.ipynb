# %%
shortid: YSEA82a
starttime: 2023/10/18 11:52:22
cst: 1697601151652
submittype: 1
ktimes: 52
hlv: 1
rn: 1884761870.14146310
jqpram: JsbfoCF4h
nw: 1
jwt: 16
jpm: 27
nip: 1
t: 1697601151658
jqnonce: 5bd21610-c8f8-4306-9431-e54e14516db1
jqsign: 7`f03432/a:d:/6124/;613/g76g36734f`3
submitdata: 1$1}2$2}3$1

# %%
shortid: YSEA82a
starttime: 2023/10/18 11:59:11
cst: 1697601557793 
submittype: 1
ktimes: 36
hlv: 1
rn: 1884761870.98152183
jqpram: svBWExX6
nw: 1
jwt: 16
jpm: 27
nip: 1
t: 1697601557799
jqnonce: 0c9a3a3f-80e5-4dbf-9e04-672c3a63e7d8
jqsign: 6e?g5g5`+>6c3+2bd`+?c62+014e5g05c1b>
submitdata: 1$1}2$1}3$1

# %%
"https://ks.wjx.top/joinnew/processjq.ashx?shortid=YSEA82a&starttime=2023%2F10%2F19%2012%3A52%3A52&cst=1697691199361&submittype=1&ktimes=97&hlv=1&rn=1884762025.24760268&jqpram=hozVaXACs&nw=1&jwt=16&jpm=27&nip=1&t=1697691199366&jqnonce=2cfe8250-6d05-49fe-a05d-cf806d7a6cfb"

# %%
data = {
    'shortid': 'YSEA82a',
    'starttime':time.strftime("%Y/%m/%d %X",time.localtime(time1)),
    'cst':str(int(time1)),
    'submittype':'1',
    'ktimes':'36',
    'hlv':'1',
    'rn':"1884762025.06925433",
    'jqpram':jqpram,
    'nw':'1',
    'jwt':'16',
    'nip':'1',
    't':str(int(time1)+10),
    'jqnonce':"99bf5150-1162-476c-8a57-012f5e328cd1",
    'jqsign':jqsign,
    'submitdata': '1$1}2$1}3$1' 
}

# %%
data
# Out:
# {'starttime': '2023/10/19 12:33:45'}

# %%
import PyExecJS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-02eabe2b0902> in <module>
# ----> 1 import PyExecJS
#
# ModuleNotFoundError: No module named 'PyExecJS'
