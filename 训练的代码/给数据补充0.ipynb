# %%
import pandas as pd
data = pd.read_excel("D:\\数学建模\\历年真题\\模拟题\\问题2.xlsx")
data = data.fillna(0)

# %%
import os
os.chdir("C:\\Users\\86139\\Desktop\\python")

# %%
data.to_excel("增加0的.xlsx")

# %%
df = pd.read_excel("C:\\Users\\86139\\Desktop\\PYTHON2\\高血压与糖尿病.xlsx")

# %%
df = df.fillna(0)

# %%
blood = df.iloc[:,1]

# %%
blood[blood == 1].count()
# Out:
# 630

# %%
sweet = df.iloc[:,8]

# %%
sweet[sweet == 1].count()
# Out:
# 224

# %%
data = pd.read_excel("C:\\Users\\86139\\Desktop\\高血压.xlsx")

# %%
for i in range(data.index.stop):
    if data.iloc[i,2]<=0.05:
        print(data.iloc[i,0])
# Out:
# 是否吸烟
# 是否饮酒
# 不吃早餐
# 是否吃大米
# 是否吃内脏类
# 是否吃酸奶
# 是否吃豆腐丝等
# 是否吃豆浆
# 是否吃新鲜蔬菜
# 是否吃果汁饮料
# 是否吃其他饮料
# 是否参加体育锻炼
