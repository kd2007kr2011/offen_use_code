# %%
import pandas as pd

# %%
data = pd.read_excel("C:\\Users\\86139\\Desktop\\英语单词.xlsx")

# %%
import random

# %%
a = data.iloc[:,0]

# %%
a.count()
# Out:
# 88

# %%
a != pd.NA
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 93    True
# 94    True
# 95    True
# 96    True
# 97    True
# Name: 第一天, Length: 98, dtype: bool

# %%
i = random.randrange(0,4)
j = random.randrange(0,data.iloc[:,i].count())
content = data.iloc[j,i]

# %%
from tkinter import *

# %%
def change_label():
    i = random.randrange(0,4)
    j = random.randrange(0,data.iloc[:,i].count())
    content = data.iloc[j,i]
    label.config(text = content)
def print_no():
    print(label.cget("text"))
    i = random.randrange(0,4)
    j = random.randrange(0,data.iloc[:,i].count())
    content = data.iloc[j,i]
    label.config(text = content)
i = random.randrange(0,4)
j = random.randrange(0,data.iloc[:,i].count())
content = data.iloc[j,i]
root = Tk()
label = Label(root,text = content,font = (None,20))
label.pack()
button = Button(root,text = "下一个",command = change_label)
button.pack()
button_1 = Button(root,text = "标记",command = print_no)
button_1.pack()
root.mainloop()
# Out:
# 一个半小时
# 安检
# 美学的表现
# 妖魔
# 特点
# 数学学家
# 政治权利
# 石油
# 钢筋混凝土
# 自古以来
# 最集中
# 西部大开发战略
# 澳门
# 辉煌的
# 紧密的
# 天堂

# %%
一个半小时
安检
美学的表现
妖魔
特点
数学学家
政治权利
石油
钢筋混凝土
自古以来
最集中
西部大开发战略
澳门
辉煌的
紧密的
天堂
